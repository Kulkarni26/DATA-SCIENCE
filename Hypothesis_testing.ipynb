# %%
# Importing necessary libraries
import numpy as np
from scipy.stats import z

# Given data
sample_mean = 3050        # observed mean weekly cost (Rs)
X_mean = 600              # mean number of units produced
sigma_X = 25              # std deviation of units produced
sample_size = 25          # number of restaurants

# %%
# Step 1: Calculate the theoretical mean cost from the cost model
# W = 1000 + 5X
theoretical_mean = 1000 + 5 * X_mean
print("Theoretical Mean: ")
print(theoretical_mean)
# Out:
# Theoretical Mean:
# 4000

# %%
# Step 3: Calculate the test statistic (z)
alpha = 5 * 25
z = (sample_mean - theoretical_mean) / (alpha / np.sqrt(sample_size))
print(z)
# Out:
# -38.0

# %%
# Step 4: Define significance level and critical value for one-tailed test
alpha = 0.05
Z_critical = norm.ppf(1 - alpha)  # right-tailed test
print(np.round(Z_critical,3))
# Out:
# 1.645

# %%
# Step 5: Make a decision
if z > Z_critical:
    print("Reject Null Hypothesis (Costs are significantly higher")
else:
    print("Fail to Reject Null Hypothesis (No significant increase)")
# Out:
# Fail to Reject Null Hypothesis (No significant increase)

# %%
# Step 6: Display results
print(f"Theoretical Mean Cost = {theoretical_mean}")
print(f"Population Std Dev (σ) = {alpha}")
print(f"Z Statistic = {z:.2f}")
print(f"Critical Z Value = {Z_critical:.2f}")
print(f"Decision: {decision}")
# Out:
# Theoretical Mean Cost = 4000
# Population Std Dev (σ) = 0.05
# Z Statistic = -38.00
# Critical Z Value = 1.64
# Decision: Fail to Reject Null Hypothesis (No significant increase)
